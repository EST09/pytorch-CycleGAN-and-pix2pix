# %%
import openslide
from openslide import open_slide
from openslide.deepzoom import DeepZoomGenerator

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os
#import valis
import cv2

import seaborn as sns

# %%
import matplotlib.pyplot as plt
im = plt.imread("/well/rittscher/users/qdv200/MPN/GAN_tiles/extra_data/bET_ihc_tiles_for_ssd/b-ET-CALR-2021-02-19-11-12-00_36096_13056.png")
plt.imshow(im)

# %%
import os

#get image mask

x_sc=100
y_sc=100

#make tiles
image = "b-ET-CALR-2021-02-19-11-12-00.ndpi"
#image = "b-ET-2021-02-08-12-25-45-CALR.ndpi"
filepath = "/well/rittscher/users/qdv200/MPN/HE-IHC-BMT/valis_slides/"

slide_path = os.path.join(filepath, image)

slide = open_slide(slide_path)

print(slide.level_dimensions[0][0]/256)
print(slide.level_dimensions[0][1]/256)
# Out:
# 350.0
# 84.0

# %%
print(350*84)
# Out:
# 29400
